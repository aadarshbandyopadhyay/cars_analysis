# %%
import pandas as pd

# %%
data_file = "./data/vehicles_clean.csv"

cars_df = pd.read_csv(data_file)

# %%
# cars_df.head(100).to_csv("./data/vehicles_small.csv", index=False)

# %%
cars_df
# Out:
#                 id                                                url  \
# 0       7316814884  https://auburn.craigslist.org/ctd/d/auburn-uni...
# 1       7316814758  https://auburn.craigslist.org/ctd/d/auburn-uni...
# 2       7316814989  https://auburn.craigslist.org/ctd/d/auburn-uni...
# 3       7316743432  https://auburn.craigslist.org/ctd/d/auburn-uni...
# 4       7316356412  https://auburn.craigslist.org/cto/d/auburn-uni...
# ...            ...                                                ...
# 383484  7301591192  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 383485  7301591187  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 383486  7301591147  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 383487  7301591140  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 383488  7301591129  https://wyoming.craigslist.org/ctd/d/atlanta-2...
#
#          region                      region_url  price    year manufacturer  \
# ...
